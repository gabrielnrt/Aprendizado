# %%
import pandas as pd

publi = pd.read_csv('http://faculty.marshall.usc.edu/gareth-james/ISL/Advertising.csv',index_col=0)
publi.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
print(type(publi))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(publi.shape)
# Out:
# (200, 4)

# %%
x = publi[['TV','radio','newspaper']]
y = publi['sales']

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
import seaborn as sns

sns.pairplot(publi, x_vars=['TV','radio','newspaper'], y_vars='sales',height=7, kind='reg')

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Importação do modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()
reglin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(reglin.coef_)
# Out:
# [0.04651658 0.18622132 0.00276254]

# %% [markdown]
# ### Previsão

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [10.04351509 14.90275602 21.09977225  8.25598146 20.74839426 16.86464752
#  17.93250371 19.49694176 19.61169806 19.95089568  7.04127035  6.00961075
#   3.51008424 18.57151213  9.09253749  7.84232371 10.25689175 12.68309664
#  16.89748523 24.21067079 20.83444892 12.36450382 20.19849587 12.33019356
#   3.4707911   6.47225929 18.52755821 18.30642002 14.0715603  20.9945215
#  11.43071612 15.40754163 14.91991818 11.56389649 10.46283745 13.73084307
#  16.32580021 12.57596377 16.36492847 13.35778683 11.90713797 16.33180742
#  15.31118838 23.91249138  4.41708431  9.60985624 11.88718721 11.19536174
#  18.18163823 16.86710816 10.50781499 21.8626341   5.90399575 10.08898799
#  19.24427741 15.65370803 13.9998275  14.70913549  8.76860855 18.46410812]

# %% [markdown]
# ### Avaliação da Performance

# %%
from sklearn import metrics
import numpy as np

# %% [markdown]
# ### MAE (Mean Absolute Error)

# %%
print(metrics.mean_absolute_error(y_test,y_prev))
# Out:
# 1.1661850653849408

# %% [markdown]
# ### MSE (Mean Squared Error)

# %%
print(metrics.mean_squared_error(y_test,y_prev))
# Out:
# 2.1424128268924116

# %% [markdown]
# ### RMSE (Root Mean Sqared Error)

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_prev)))
# Out:
# 1.4636983387612392
