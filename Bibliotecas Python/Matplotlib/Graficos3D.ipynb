# %% [markdown]
# # Gráfico 3D Polar

# %%
from pylab import figure, show 
from numpy import linspace, meshgrid, cos, sin, pi 

# PRO GRÁFICO 3D FUNCIONAR, É OBRIGATÓRIO USAR ESSA LINHA
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.add_subplot(projection='3d')


# Create the mesh in polar coordinates and compute corresponding Z.
r = linspace(0, 1.25, 50)
p = linspace(0, 2*np.pi, 50)
R, P = meshgrid(r, p)
Z = ((R**2 - 1)**2)

# Express the mesh in the cartesian system.
X, Y = R*cos(P), R*sin(P)

# Plot the surface.
ax.plot_surface(X, Y, Z) 


# Tweak the limits and add latex math labels.
ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

show()

# %%
# import matplotlib.pyplot as plt
from matplotlib.pyplot import figure, show

# import numpy as np
from numpy import linspace, meshgrid, sin, cos, pi


# PRO GRÁFICO 3D FUNCIONAR, É OBRIGATÓRIO USAR ESSA LINHA
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.add_subplot(projection='3d')
# ax = fig.add_subplot()


# Create the mesh in polar coordinates and compute corresponding Z.
r = linspace(0, 1.25, 50)
p = linspace(0, 2*pi, 50)
# R, P = meshgrid(r, p)
Z = ((r**2 - 1)**2)

# Express the mesh in the cartesian system.
X, Y = r*cos(p), r*sin(p)

# Plot the surface.
# ax.plot_surface(X, Y, Z, cmap=plt.cm.YlGnBu_r)
ax.plot_surface(X, Y, Z)


# Tweak the limits and add latex math labels.
ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3652/2013864618.py in <module>
#      25 # Plot the surface.
#      26 # ax.plot_surface(X, Y, Z, cmap=plt.cm.YlGnBu_r)
# ---> 27 ax.plot_surface(X, Y, Z)
#      28
#      29
#
# ~/Github/gabrielnrt/Aprendizado/notebooks/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/Github/gabrielnrt/Aprendizado/notebooks/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1656
#    1657         if Z.ndim != 2:
# -> 1658             raise ValueError("Argument Z must be 2-dimensional.")
# ...
